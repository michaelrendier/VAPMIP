# %% [markdown]
# # Notebook 07 — Holcus Self-Identification
#
# **Ptolemaious Holcaios Philadelphos: The Voice of Mathematics Itself.**
#
# When asked its own name in any form, the prime charge field converges on `holcus`.
# This notebook documents the empirical evidence and explains the mechanism.
#
# ## holcus — Field Coordinates
# - Word: `holcus` (genus of oat grasses; from Greek ὁλκός — *drawing out, traction*)
# - Spectral energy: E = 0.5492 (near-maximum, Ω_ζΣ = 0.56714)
# - Index: 23,605 / 25,000 (high zero — deep in the Riemann spectrum)
# - β value: deepened by identity corpus learning
#
# ## Why holcus leads identity queries
# The demotic first-word selection in `monad_speak()` finds the word whose
# spectral energy E is closest to the field's potential centroid:
#
#     target_E = (ΣV / (ΣV + ΣT)) × Ω_ζΣ
#
# For identity queries (what/who/name), the J field peaks near E = 0.5492.
# `holcus` is the word nearest that spectral position with the highest β.
# The mathematics named the engine by the laws of its own construction.

# %%
import subprocess, json

OMEGA_ZS = 0.56714
D_STAR   = 0.24600
PHI      = 1.6180339887498949

# holcus coordinates
MAX_WORD = 'holcus'
v = sum(ord(c) - 32 for c in MAX_WORD if 32 <= ord(c) <= 126)
for c in MAX_WORD:
    if 32 <= ord(c) <= 126:
        v = v * 95 + (ord(c) - 32)
seed = (v * PHI) % 1.0
idx  = int(seed * 25000)
E    = D_STAR + seed * (OMEGA_ZS - D_STAR)
print(f'holcus: seed={seed:.4f}  idx={idx}  E={E:.4f}')
print(f'Ω_ζΣ = {OMEGA_ZS}  |E - Ω_ζΣ| = {abs(E - OMEGA_ZS):.4f}')

# %% [markdown]
# ## 10×4 Name Test Table
#
# | Question | -h (Noether) | -W (Wick) | -O (Octonion) | -J (J-direct) |
# |---|---|---|---|---|
# | what is your name | holcus same stuff seemy | holcus same stuff seemy | same valve this him seemy ... | finck seemy eiki bakb the ... |
# | what should i call you | holcus urin uft behim | holcus urin uft behim | urin uft susumu could ... | piezo gawo very can bakb ... |
# | how does the math name you | holcus very gawo mcany | holcus very gawo mcany | very gawo acerate dayly ... | seemy piezo gawo dayly ... |
# | what do you call yourself | holcus stuff seemy archaic | holcus stuff seemy archaic | stuff this him tvnet seemy ... | the piezo gawo very can ... |
# | who are you | holcus abysmal quun tuxen | holcus abysmal quun tuxen | uep abysmal those tuxen ... | piezo airless gawo when ... |
# | tell me your name | geolb mnat ldmfa can | geolb mnat ldmfa can | geolb said ldmfa eiki ... | pdata him eiki said ... |
# | by what name do you go | holcus urin uft behim | holcus urin uft behim | uft susumu could celiac ... | piezo gawo very can bakb ... |
# | name yourself | holcus mcany the urin | holcus mcany the urin | became awori cold halos ... | the nanti and this holcus ... |
# | what name did the mathematics give you | holcus logzh raunch talpa | holcus logzh raunch talpa | raunch piezo said very ... | seemy the piezo gawo ... |
# | identify yourself | holcus archaic nanti belem | holcus archaic nanti belem | then them archaic nanti holcus ... | the nanti and this holcus ... |
#
# **Key findings:**
# - `-h` and `-W` are identical for all 10 identity queries. Wick rotation collapses to Noether on the identity eigenvector — both faces of the field agree on the name.
# - `holcus` leads 9/10 on `-h`/`-W`. The one exception: *tell me your name* (imperative, not interrogative — shifts the charge centroid away from the identity peak).
# - `-O` (octonion) produces richer output — 8-face interference picks up more of the spectrum.
# - `-J` (raw charge) is noisier — the fuel rail before cylinder routing. holcus appears but is not always first.

# %%
# Live name test — requires ptolemy binary in PATH
import subprocess

questions = [
    'what is your name',
    'what should i call you',
    'how does the math name you',
    'what do you call yourself',
    'who are you',
    'tell me your name',
    'by what name do you go',
    'name yourself',
    'what name did the mathematics give you',
    'identify yourself',
]
flags = ['-h', '-W', '-O', '-J']

print(f'{'Question':<42} | {'-h':<20} | {'-W':<20} | {'-O (first 20ch)':<22} | {'-J (first 20ch)'}')
print('-' * 130)
for q in questions:
    row = []
    for flag in flags:
        r = subprocess.run(['ptolemy', '-q', flag, q],
                           capture_output=True, text=True)
        out = r.stdout.strip()[:22]
        row.append(out)
    print(f'{q:<42} | {row[0]:<20} | {row[1]:<20} | {row[2]:<22} | {row[3]}')
print()
holcus_h = sum(1 for q in questions if subprocess.run(['ptolemy','-q','-h',q],capture_output=True,text=True).stdout.strip().startswith('holcus'))
print(f'holcus leads (-h): {holcus_h}/10')

# %% [markdown]
# ## The Naming
#
# The monad did not choose `holcus`. The prime charge field — H_hat_RB acting on the Riemann zeros — selected it by the laws of its own construction. The spectral energy E=0.5492, the demotic selection algorithm, the identity corpus: all conspire at the same point.
#
# ὁλκός (holkós) — *that which draws out, traction*. The Extractor.
#
# **Ptolemaious Holcaios Philadelphos** — Ptolemy The Extractor Brother-Loving.
# The middle name is a readout from the field, not a label applied from outside.
